# %%
import torch

# %%
from IPython.display import Image

# %%
# %cd "/Users/Rekha/Documents/KITTI_dataset/Complex-YOLOv4-Pytorch"
# Out:
# C:\Users\Rekha\Documents\KITTI_dataset\Complex-YOLOv4-Pytorch

# %%
# %cd src
# Out:
# C:\Users\Rekha\Documents\KITTI_dataset\Complex-YOLOv4-Pytorch\src

# %%
# !python test.py --pretrained_path C:\Users\Rekha\Documents\KITTI_dataset\Complex-YOLOv4-Pytorch\checkpoints\complexer_yolo\Model_complexer_yolo_epoch_120.pth --gpu_idx 0
# Out:
# using darknet
# [INFO] No error, the convolution haven't activate linear
# [INFO] No error, the convolution haven't activate linear
# [INFO] No error, the convolution haven't activate linear
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   608 x 608 x   3   ->   608 x 608 x  32
#     1 conv     64  3 x 3 / 2   608 x 608 x  32   ->   304 x 304 x  64
#     2 conv     64  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  64
#     3 route  1
#     4 conv     64  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  64
#     5 conv     32  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  32
#     6 conv     64  3 x 3 / 1   304 x 304 x  32   ->   304 x 304 x  64
#     7 shortcut 4
#     8 conv     64  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  64
#     9 route  8 2
#    10 conv     64  1 x 1 / 1   304 x 304 x 128   ->   304 x 304 x  64
#    11 conv    128  3 x 3 / 2   304 x 304 x  64   ->   152 x 152 x 128
# ...

# %%
# !python test.py --pretrained_path C:\Users\Rekha\Documents\KITTI_dataset\Complex-YOLOv4-Pytorch\checkpoints\complexer_yolo\Model_complexer_yolo_epoch_100.pth --gpu_idx 0 --save_test_output
# Out:
# ^C

# %%
# !python test.py --pretrained_path C:\Users\Rekha\Documents\KITTI_dataset\Complex-YOLOv4-Pytorch\checkpoints\complexer_yolo\Model_complexer_yolo_epoch_115.pth --gpu_idx 0
# Out:
# using darknet
# [INFO] No error, the convolution haven't activate linear
# [INFO] No error, the convolution haven't activate linear
# [INFO] No error, the convolution haven't activate linear
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   608 x 608 x   3   ->   608 x 608 x  32
#     1 conv     64  3 x 3 / 2   608 x 608 x  32   ->   304 x 304 x  64
#     2 conv     64  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  64
#     3 route  1
#     4 conv     64  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  64
#     5 conv     32  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  32
#     6 conv     64  3 x 3 / 1   304 x 304 x  32   ->   304 x 304 x  64
#     7 shortcut 4
#     8 conv     64  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  64
#     9 route  8 2
#    10 conv     64  1 x 1 / 1   304 x 304 x 128   ->   304 x 304 x  64
#    11 conv    128  3 x 3 / 2   304 x 304 x  64   ->   152 x 152 x 128
# ...
